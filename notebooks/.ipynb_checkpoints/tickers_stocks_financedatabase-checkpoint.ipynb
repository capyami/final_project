# %%
import financedatabase as fd
import pandas as pd

# %%
equities = fd.Equities()

# %%
equities_countries = equities.options('country')
equities_countries

# %%
equities_sectors = equities.options('sector')
equities_sectors

# %%
equities_industry_groups = equities.options('industry_group')
equities_industry_groups

# %%
equities_germany_industries = equities.options('industry', country='Germany')
equities_germany_industries
# Out:
# array(['Aerospace & Defense', 'Air Freight & Logistics', 'Airlines',
#        'Auto Components', 'Automobiles', 'Banks', 'Beverages',
#        'Biotechnology', 'Building Products', 'Capital Markets',
#        'Chemicals', 'Commercial Services & Supplies',
#        'Communications Equipment', 'Construction & Engineering',
#        'Construction Materials', 'Consumer Finance', 'Distributors',
#        'Diversified Consumer Services', 'Diversified Financial Services',
#        'Diversified Telecommunication Services', 'Electric Utilities',
#        'Electrical Equipment',
#        'Electronic Equipment, Instruments & Components', 'Entertainment',
#        'Equity Real Estate Investment Trusts (REITs)',
#        'Food & Staples Retailing', 'Health Care Equipment & Supplies',
#        'Health Care Providers & Services', 'Health Care Technology',
#        'Hotels, Restaurants & Leisure', 'Household Durables',
#        'Household Products', 'IT Services',
#        'Independent Power and Renewable Electricity Producers',
#        'Industrial Conglomerates', 'Insurance',
#        'Interactive Media & Services',
#        'Internet & Direct Marketing Retail', 'Machinery', 'Marine',
#        'Media', 'Metals & Mining', 'Multi-Utilities',
#        'Oil, Gas & Consumable Fuels', 'Paper & Forest Products',
#        'Pharmaceuticals', 'Professional Services',
#        'Real Estate Management & Development', 'Road & Rail',
#        'Semiconductors & Semiconductor Equipment', 'Software',
#        'Specialty Retail', 'Technology Hardware, Storage & Peripherals',
#        'Textiles, Apparel & Luxury Goods', 'Thrifts & Mortgage Finance',
#        'Trading Companies & Distributors',
#        'Transportation Infrastructure', 'Water Utilities'], dtype=object)

# %%
equities_united_states = equities.select(country="United States")
equities_united_states
# Out:
#                                            name  \
# symbol
# A                    Agilent Technologies, Inc.
# AA                            Alcoa Corporation
# AABB                       Asia Broadband, Inc.
# AAC                Ares Acquisition Corporation
# AACI    Armada Acquisition Corp. I Common Stock
# ...                                         ...
# ZYJT             Zhong Ya International Limited
# ZYNE              Zynerba Pharmaceuticals, Inc.
# ZYRX           Zyrox Mining International, Inc.
# ZYXI                                Zynex, Inc.
# ZZZOF                                       one
#
#                                                   summary currency  \
# symbol
# A       Agilent Technologies, Inc. provides applicatio...      USD
# AA      Alcoa Corporation, together with its subsidiar...      USD
# AABB    Asia Broadband Inc., through its subsidiary, A...      USD
# AAC     Ares Acquisition Corporation focuses on effect...      USD
# AACI                                                  NaN      USD
# ...                                                   ...      ...
# ZYJT    Zhong Ya International Limited does not have s...      USD
# ZYNE    Zynerba Pharmaceuticals, Inc. operates as a cl...      USD
# ZYRX    WSPVA Bio Products International, LLC engages ...      USD
# ZYXI    Zynex, Inc., through its subsidiaries, designs...      USD
# ZZZOF   one does not have significant operations. It i...      USD
#
#                         sector  \
# symbol
# A                  Health Care
# AA                   Materials
# AABB                 Materials
# AAC                 Financials
# AACI                Financials
# ...                        ...
# ZYJT                Financials
# ZYNE               Health Care
# ZYRX    Consumer Discretionary
# ZYXI               Health Care
# ZZZOF               Financials
#
#                                         industry_group  \
# symbol
# A       Pharmaceuticals, Biotechnology & Life Sciences
# AA                                           Materials
# AABB                                         Materials
# AAC                             Diversified Financials
# AACI                            Diversified Financials
# ...                                                ...
# ZYJT                            Diversified Financials
# ZYNE    Pharmaceuticals, Biotechnology & Life Sciences
# ZYRX                          Automobiles & Components
# ZYXI                  Health Care Equipment & Services
# ZZZOF                           Diversified Financials
#
#                               industry exchange                   market  \
# symbol
# A                        Biotechnology      NYQ  New York Stock Exchange
# AA                     Metals & Mining      NYQ  New York Stock Exchange
# AABB                   Metals & Mining      PNK       OTC Bulletin Board
# AAC     Diversified Financial Services      NYQ  New York Stock Exchange
# AACI    Diversified Financial Services      NMS     NASDAQ Global Select
# ...                                ...      ...                      ...
# ZYJT    Diversified Financial Services      PNK       OTC Bulletin Board
# ZYNE                   Pharmaceuticals      NGM     Nordic Growth Market
# ZYRX                   Auto Components      PNK       OTC Bulletin Board
# ZYXI            Health Care Technology      NCM    NASDAQ Capital Market
# ZZZOF   Diversified Financial Services      PNK       OTC Bulletin Board
#
#               country state           city     zipcode  \
# symbol
# A       United States    CA    Santa Clara       95051
# AA      United States    PA     Pittsburgh  15212-5858
# AABB    United States    NV      Las Vegas       89135
# AAC     United States    NY       New York       10167
# AACI    United States   NaN            NaN         NaN
# ...               ...   ...            ...         ...
# ZYJT    United States    NV      Henderson       89074
# ZYNE    United States    PA          Devon       19333
# ZYRX    United States    CA       Monterey       93940
# ZYXI    United States    CO      Englewood       80112
# ZZZOF   United States    CA  San Francisco       94129
#
#                                  website market_cap          isin      cusip  \
# symbol
# A                 http://www.agilent.com  Large Cap  US00846U1016  00846U101
# AA                  http://www.alcoa.com    Mid Cap  US0138721065   13872106
# AABB     http://www.asiabroadbandinc.com  Micro Cap           NaN        NaN
# AAC                                  NaN  Small Cap  AU000000AAC9        NaN
# AACI                                 NaN   Nano Cap           NaN        NaN
# ...                                  ...        ...           ...        ...
# ZYJT                                 NaN   Nano Cap           NaN        NaN
# ZYNE                  http://zynerba.com   Nano Cap  US98986X1090  98986X109
# ZYRX    http://www.dissolvingplastic.com   Nano Cap           NaN        NaN
# ZYXI                http://www.zynex.com  Small Cap           NaN        NaN
# ZZZOF               http://www.a-star.co  Small Cap           NaN        NaN
#
#                 figi composite_figi shareclass_figi
# symbol
# A       BBG000C2V541   BBG000C2V3D6    BBG001SCTQY4
# AA      BBG00B3T3HK5   BBG00B3T3HD3    BBG00B3T3HF1
# AABB             NaN            NaN             NaN
# AAC              NaN            NaN             NaN
# AACI             NaN            NaN             NaN
# ...              ...            ...             ...
# ZYJT             NaN            NaN             NaN
# ZYNE             NaN            NaN             NaN
# ZYRX             NaN            NaN             NaN
# ZYXI             NaN            NaN             NaN
# ZZZOF            NaN            NaN             NaN
#
# [13140 rows x 19 columns]

# %%
equities_country = equities.options('country')
equities_country
# Out:
# array(['Afghanistan', 'Anguilla', 'Argentina', 'Australia', 'Austria',
#        'Azerbaijan', 'Bahamas', 'Bangladesh', 'Barbados', 'Belgium',
#        'Belize', 'Bermuda', 'Botswana', 'Brazil',
#        'British Virgin Islands', 'Cambodia', 'Canada', 'Cayman Islands',
#        'Chile', 'China', 'Colombia', 'Costa Rica', 'Cyprus',
#        'Czech Republic', 'Denmark', 'Dominican Republic', 'Egypt',
#        'Estonia', 'Falkland Islands', 'Finland', 'France',
#        'French Guiana', 'Gabon', 'Georgia', 'Germany', 'Ghana',
#        'Gibraltar', 'Greece', 'Greenland', 'Guernsey', 'Hong Kong',
#        'Hungary', 'Iceland', 'India', 'Indonesia', 'Ireland',
#        'Isle of Man', 'Israel', 'Italy', 'Ivory Coast', 'Japan', 'Jersey',
#        'Jordan', 'Kazakhstan', 'Kenya', 'Kyrgyzstan', 'Latvia',
#        'Liechtenstein', 'Lithuania', 'Luxembourg', 'Macau', 'Macedonia',
#        'Malaysia', 'Malta', 'Mauritius', 'Mexico', 'Monaco', 'Mongolia',
#        'Montenegro', 'Morocco', 'Mozambique', 'Myanmar', 'Namibia',
#        'Netherlands', 'Netherlands Antilles', 'New Zealand', 'Nigeria',
#        'Norway', 'Panama', 'Papua New Guinea', 'Peru', 'Philippines',
#        'Poland', 'Portugal', 'Qatar', 'Reunion', 'Romania', 'Russia',
#        'Saudi Arabia', 'Senegal', 'Singapore', 'Slovakia', 'Slovenia',
#        'South Africa', 'South Korea', 'Spain', 'Suriname', 'Sweden',
#        'Switzerland', 'Taiwan', 'Tanzania', 'Thailand', 'Turkey',
#        'Ukraine', 'United Arab Emirates', 'United Kingdom',
#        'United States', 'Uruguay', 'Vietnam', 'Zambia'], dtype=object)

# %%
equities_usa_consumer_electronics = equities.select(country="United States", industry="Consumer Electronics")
equities_usa_consumer_electronics
# Out:
# Empty DataFrame
# Columns: [name, summary, currency, sector, industry_group, industry, exchange, market, country, state, city, zipcode, website, market_cap, isin, cusip, figi, composite_figi, shareclass_figi]
# Index: []

# %%
stocks = pd.DataFrame(equities.select())
stocks
# Out:
#                                             name  \
# symbol
# A                     Agilent Technologies, Inc.
# AA                             Alcoa Corporation
# AAALF                             Aareal Bank AG
# AAALY                             Aareal Bank AG
# AABB                        Asia Broadband, Inc.
# ...                                          ...
# NaN     Nano Labs Ltd American Depositary Shares
# NaN     Nano Labs Ltd American Depositary Shares
# NaN     Nano Labs Ltd American Depositary Shares
# NaN     Nano Labs Ltd American Depositary Shares
# NaN     Nano Labs Ltd American Depositary Shares
#
#                                                   summary currency  \
# symbol
# A       Agilent Technologies, Inc. provides applicatio...      USD
# AA      Alcoa Corporation, together with its subsidiar...      USD
# AAALF   Aareal Bank AG, together with its subsidiaries...      USD
# AAALY   Aareal Bank AG, together with its subsidiaries...      USD
# AABB    Asia Broadband Inc., through its subsidiary, A...      USD
# ...                                                   ...      ...
# NaN                                                   NaN      USD
# NaN                                                   NaN      USD
# NaN                                                   NaN      USD
# NaN                                                   NaN      USD
# NaN                                                   NaN      USD
#
#                         sector  \
# symbol
# A                  Health Care
# AA                   Materials
# AAALF               Financials
# AAALY               Financials
# AABB                 Materials
# ...                        ...
# NaN     Information Technology
# NaN     Information Technology
# NaN     Information Technology
# NaN     Information Technology
# NaN     Information Technology
#
#                                         industry_group  \
# symbol
# A       Pharmaceuticals, Biotechnology & Life Sciences
# AA                                           Materials
# AAALF                                            Banks
# AAALY                                            Banks
# AABB                                         Materials
# ...                                                ...
# NaN           Semiconductors & Semiconductor Equipment
# NaN           Semiconductors & Semiconductor Equipment
# NaN           Semiconductors & Semiconductor Equipment
# NaN           Semiconductors & Semiconductor Equipment
# NaN           Semiconductors & Semiconductor Equipment
#
#                                         industry exchange  \
# symbol
# A                                  Biotechnology      NYQ
# AA                               Metals & Mining      NYQ
# AAALF                                      Banks      PNK
# AAALY                                      Banks      PNK
# AABB                             Metals & Mining      PNK
# ...                                          ...      ...
# NaN     Semiconductors & Semiconductor Equipment      NMS
# NaN     Semiconductors & Semiconductor Equipment      NMS
# NaN     Semiconductors & Semiconductor Equipment      NMS
# NaN     Semiconductors & Semiconductor Equipment      NMS
# NaN     Semiconductors & Semiconductor Equipment      NMS
#
#                          market        country state         city     zipcode  \
# symbol
# A       New York Stock Exchange  United States    CA  Santa Clara       95051
# AA      New York Stock Exchange  United States    PA   Pittsburgh  15212-5858
# AAALF        OTC Bulletin Board        Germany   NaN    Wiesbaden       65189
# AAALY        OTC Bulletin Board        Germany   NaN    Wiesbaden       65189
# AABB         OTC Bulletin Board  United States    NV    Las Vegas       89135
# ...                         ...            ...   ...          ...         ...
# NaN        NASDAQ Global Select          China   NaN          NaN         NaN
# NaN        NASDAQ Global Select          China   NaN          NaN         NaN
# NaN        NASDAQ Global Select          China   NaN          NaN         NaN
# NaN        NASDAQ Global Select          China   NaN          NaN         NaN
# NaN        NASDAQ Global Select          China   NaN          NaN         NaN
#
#                                 website market_cap          isin      cusip  \
# symbol
# A                http://www.agilent.com  Large Cap  US00846U1016  00846U101
# AA                 http://www.alcoa.com    Mid Cap  US0138721065   13872106
# AAALF        http://www.aareal-bank.com  Small Cap  US00254K1088  00254K108
# AAALY        http://www.aareal-bank.com  Small Cap  US00254K1088  00254K108
# AABB    http://www.asiabroadbandinc.com  Micro Cap           NaN        NaN
# ...                                 ...        ...           ...        ...
# NaN                                 NaN  Micro Cap           NaN        NaN
# NaN                                 NaN  Micro Cap           NaN        NaN
# NaN                                 NaN  Micro Cap           NaN        NaN
# NaN                                 NaN  Micro Cap           NaN        NaN
# NaN                                 NaN  Micro Cap           NaN        NaN
#
#                 figi composite_figi shareclass_figi
# symbol
# A       BBG000C2V541   BBG000C2V3D6    BBG001SCTQY4
# AA      BBG00B3T3HK5   BBG00B3T3HD3    BBG00B3T3HF1
# AAALF            NaN            NaN             NaN
# AAALY            NaN            NaN             NaN
# AABB             NaN            NaN             NaN
# ...              ...            ...             ...
# NaN              NaN            NaN             NaN
# NaN              NaN            NaN             NaN
# NaN              NaN            NaN             NaN
# NaN              NaN            NaN             NaN
# NaN              NaN            NaN             NaN
#
# [22812 rows x 19 columns]

# %%
equities.search(summary='automotive', currency='USD', country='Germany')

# %%
equities = fd.Equities()

equities_per_sector_netherlands = {}

for sector in equities.options(selection='sector', country='Netherlands'):
    try:
        equities_per_sector_netherlands[sector] = len(equities.select(country='Netherlands', sector=sector))
    except ValueError as error:
        print(error)

# %%
equities_per_sector_netherlands
# Out:
# {'Communication Services': 9,
#  'Consumer Discretionary': 12,
#  'Consumer Staples': 7,
#  'Energy': 9,
#  'Financials': 13,
#  'Health Care': 16,
#  'Industrials': 15,
#  'Information Technology': 13,
#  'Materials': 9,
#  'Real Estate': 2,
#  'Utilities': 0}

# %%
equities = fd.Equities()

silicon_valley = equities.search(sector='Technology', city='San Jose')

# %%
silicon_valley
# Out:
#                                  name  \
# symbol
# 0A4Q.L         QuickLogic Corporation
# 0HS2.L   Cadence Design Systems, Inc.
# 0IH3.L           Energous Corporation
# 0JVV.L         Lumentum Holdings Inc.
# 0K9O.L                  Nutanix, Inc.
# ...                               ...
# XLNX.VI                  Xilinx, Inc.
# XPER        Xperi Holding Corporation
# YTY.V               Wi2Wi Corporation
# ZS                      Zscaler, Inc.
# ZS.MX                   Zscaler, Inc.
#
#                                                    summary currency  \
# symbol
# 0A4Q.L   QuickLogic Corporation, a semiconductor compan...      USD
# 0HS2.L   Cadence Design Systems, Inc. provides software...      USD
# 0IH3.L   Energous Corporation develops wire-free chargi...      USD
# 0JVV.L   Lumentum Holdings Inc. manufactures and sells ...      USD
# 0K9O.L   Nutanix, Inc. develops and provides an enterpr...      USD
# ...                                                    ...      ...
# XLNX.VI  Xilinx, Inc. designs and develops programmable...      EUR
# XPER     Xperi Holding Corporation, together with its s...      USD
# YTY.V    Wi2Wi Corporation designs, integrates, and man...      CAD
# ZS       Zscaler, Inc. operates as a cloud security com...      USD
# ZS.MX    Zscaler, Inc. operates as a cloud security com...      MXN
#
#                          sector                            industry_group  \
# symbol
# 0A4Q.L   Information Technology  Semiconductors & Semiconductor Equipment
# 0HS2.L   Information Technology                       Software & Services
# 0IH3.L   Information Technology           Technology Hardware & Equipment
# 0JVV.L   Information Technology           Technology Hardware & Equipment
# 0K9O.L   Information Technology                       Software & Services
# ...                         ...                                       ...
# XLNX.VI  Information Technology  Semiconductors & Semiconductor Equipment
# XPER     Information Technology  Semiconductors & Semiconductor Equipment
# YTY.V    Information Technology           Technology Hardware & Equipment
# ZS       Information Technology                       Software & Services
# ZS.MX    Information Technology                       Software & Services
#
#                                                industry exchange  \
# symbol
# 0A4Q.L         Semiconductors & Semiconductor Equipment      LSE
# 0HS2.L                                         Software      LSE
# 0IH3.L   Electronic Equipment, Instruments & Components      LSE
# 0JVV.L                         Communications Equipment      LSE
# 0K9O.L                                         Software      LSE
# ...                                                 ...      ...
# XLNX.VI        Semiconductors & Semiconductor Equipment      VIE
# XPER           Semiconductors & Semiconductor Equipment      NMS
# YTY.V                          Communications Equipment      VAN
# ZS                                             Software      NMS
# ZS.MX                                          Software      MEX
#
#                                         market        country state      city  \
# symbol
# 0A4Q.L   London Stock Exchange (international)  United States    CA  San Jose
# 0HS2.L   London Stock Exchange (international)  United States    CA  San Jose
# 0IH3.L   London Stock Exchange (international)  United States    CA  San Jose
# 0JVV.L   London Stock Exchange (international)  United States    CA  San Jose
# 0K9O.L   London Stock Exchange (international)  United States    CA  San Jose
# ...                                        ...            ...   ...       ...
# XLNX.VI                  Vienna Stock Exchange  United States    CA  San Jose
# XPER                      NASDAQ Global Select  United States    CA  San Jose
# YTY.V                     TSX Venture Exchange  United States    CA  San Jose
# ZS                        NASDAQ Global Select  United States    CA  San Jose
# ZS.MX                    Mexico Stock Exchange  United States    CA  San Jose
#
#         zipcode                    website market_cap          isin  \
# symbol
# 0A4Q.L    95131  http://www.quicklogic.com  Micro Cap           NaN
# 0HS2.L    95134     http://www.cadence.com  Large Cap  US1273871087
# 0IH3.L    95134    http://www.energous.com  Micro Cap  US29272C1036
# 0JVV.L    95131    http://www.lumentum.com    Mid Cap  GB00BLD4ZP54
# 0K9O.L    95110     http://www.nutanix.com    Mid Cap  US67059N1081
# ...         ...                        ...        ...           ...
# XLNX.VI   95124      http://www.xilinx.com  Large Cap           NaN
# XPER      95134       http://www.xperi.com  Small Cap           NaN
# YTY.V     95131       http://www.wi2wi.com   Nano Cap           NaN
# ZS        95134     http://www.zscaler.com  Large Cap  US98980G1022
# ZS.MX     95134     http://www.zscaler.com  Large Cap  US98980G1022
#
#              cusip          figi composite_figi shareclass_figi
# symbol
# 0A4Q.L         NaN           NaN            NaN             NaN
# 0HS2.L   127387108           NaN            NaN             NaN
# 0IH3.L   29272C103           NaN            NaN             NaN
# 0JVV.L         NaN           NaN            NaN             NaN
# 0K9O.L   67059N108           NaN            NaN             NaN
# ...            ...           ...            ...             ...
# XLNX.VI        NaN           NaN            NaN             NaN
# XPER           NaN           NaN            NaN             NaN
# YTY.V          NaN           NaN            NaN             NaN
# ZS       98980G102  BBG00K4MD5L3   BBG003338H34    BBG003338H61
# ZS.MX    98980G102           NaN            NaN             NaN
#
# [152 rows x 19 columns]
