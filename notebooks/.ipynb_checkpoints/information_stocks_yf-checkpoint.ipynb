# %% [markdown]
# # Filters investments

# %%
import yfinance as yf
import pandas as pd
import numpy as np
from selenium import webdriver

# %% [markdown]
# # yahoo finance

# %% [markdown]
# https://github.com/ranaroussi/yfinance/blob/main/README.md

# %% [markdown]
# https://github.com/ranaroussi/yfinance/wiki/Ticker

# %%
msft = yf.Ticker('MSFT')

# %%
pd.DataFrame(msft.info).T.head(60)
# Out:
#                                                                               0  \
# address1                                                      One Microsoft Way
# city                                                                    Redmond
# state                                                                        WA
# zip                                                                  98052-6399
# country                                                           United States
# phone                                                              425 882 8080
# fax                                                                425 706 7329
# website                                               https://www.microsoft.com
# industry                                                Software—Infrastructure
# industryDisp                                            Software—Infrastructure
# sector                                                               Technology
# ...

# %%
pd.DataFrame(msft.info).T.tail(60)
# Out:
#                                                              0  \
# impliedSharesOutstanding                                     0
# bookValue                                               26.178
# priceToBook                                          12.881809
# lastFiscalYearEnd                                   1656547200
# nextFiscalYearEnd                                   1688083200
# mostRecentQuarter                                   1680220800
# earningsQuarterlyGrowth                                  0.094
# netIncomeToCommon                                  69020000256
# trailingEps                                               9.24
# forwardEps                                               10.95
# pegRatio                                                  2.89
# lastSplitFactor                                            2:1
# lastSplitDate                                       1045526400
# enterpriseToRevenue                                     11.958
# ...

# %%
pd.DataFrame(msft.info).T.reset_index()['index'].unique()
# Out:
# array(['address1', 'city', 'state', 'zip', 'country', 'phone', 'fax',
#        'website', 'industry', 'industryDisp', 'sector',
#        'longBusinessSummary', 'fullTimeEmployees', 'companyOfficers',
#        'auditRisk', 'boardRisk', 'compensationRisk',
#        'shareHolderRightsRisk', 'overallRisk', 'governanceEpochDate',
#        'compensationAsOfEpochDate', 'maxAge', 'priceHint',
#        'previousClose', 'open', 'dayLow', 'dayHigh',
#        'regularMarketPreviousClose', 'regularMarketOpen',
#        'regularMarketDayLow', 'regularMarketDayHigh', 'dividendRate',
#        'dividendYield', 'exDividendDate', 'payoutRatio',
#        'fiveYearAvgDividendYield', 'beta', 'trailingPE', 'forwardPE',
#        'volume', 'regularMarketVolume', 'averageVolume',
#        'averageVolume10days', 'averageDailyVolume10Day', 'bid', 'ask',
#        'bidSize', 'askSize', 'marketCap', 'fiftyTwoWeekLow',
#        'fiftyTwoWeekHigh', 'priceToSalesTrailing12Months',
# ...

# %%
msft.history(period = '1mo')
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2023-06-08 00:00:00-04:00  323.940002  326.640015  323.350006  325.260010
# 2023-06-09 00:00:00-04:00  324.989990  329.989990  324.410004  326.790009
# 2023-06-12 00:00:00-04:00  328.579987  332.100006  325.160004  331.850006
# 2023-06-13 00:00:00-04:00  334.470001  336.980011  330.390015  334.290009
# 2023-06-14 00:00:00-04:00  334.339996  339.040009  332.809998  337.339996
# 2023-06-15 00:00:00-04:00  337.480011  349.839996  337.200012  348.100006
# 2023-06-16 00:00:00-04:00  351.320007  351.470001  341.950012  342.329987
# 2023-06-20 00:00:00-04:00  339.309998  342.079987  335.859985  338.049988
# 2023-06-21 00:00:00-04:00  336.369995  337.730011  332.070007  333.559998
# 2023-06-22 00:00:00-04:00  334.119995  340.119995  333.339996  339.709991
# 2023-06-23 00:00:00-04:00  334.359985  337.959991  333.450012  335.019989
# 2023-06-26 00:00:00-04:00  333.720001  336.109985  328.489990  328.600006
# ...

# %%
msft.history_metadata
# Out:
# {'currency': 'USD',
#  'symbol': 'MSFT',
#  'exchangeName': 'NMS',
#  'instrumentType': 'EQUITY',
#  'firstTradeDate': 511108200,
#  'regularMarketTime': 1688760004,
#  'gmtoffset': -14400,
#  'timezone': 'EDT',
#  'exchangeTimezoneName': 'America/New_York',
#  'regularMarketPrice': 337.22,
#  'chartPreviousClose': 323.38,
#  'priceHint': 2,
#  'currentTradingPeriod': {'pre': {'timezone': 'EDT',
#    'start': 1688976000,
#    'end': 1688995800,
#    'gmtoffset': -14400},
#   'regular': {'timezone': 'EDT',
#    'start': 1688995800,
#    'end': 1689019200,
#    'gmtoffset': -14400},
#   'post': {'timezone': 'EDT',
#    'start': 1689019200,
#    'end': 1689033600,
#    'gmtoffset': -14400}},
#  'dataGranularity': '1d',
#  'range': '1mo',
#  'validRanges': ['1d',
#   '5d',
#   '1mo',
#   '3mo',
#   '6mo',
#   '1y',
#   '2y',
#   '5y',
#   '10y',
#   'ytd',
#   'max']}

# %%
msft.actions
# Out:
# Empty DataFrame
# Columns: [Dividends, Stock Splits]
# Index: []

# %%
msft.dividends
# Out:
# Series([], Name: Dividends, dtype: float64)

# %%
msft.splits
# Out:
# Series([], Name: Stock Splits, dtype: float64)

# %%
msft.capital_gains
# Out:
# []

# %%
msft.get_shares_full(start= '2022-01-01', end= None)
# Out:
# 2022-01-27 00:00:00-05:00    7496869888
# 2022-02-04 00:00:00-05:00    7800719872
# 2022-02-05 00:00:00-05:00    7496869888
# 2022-02-11 00:00:00-05:00    7496869888
# 2022-03-04 00:00:00-05:00    7605040128
# 2022-03-05 00:00:00-05:00    7496869888
# 2022-03-16 00:00:00-04:00    7595310080
# 2022-03-17 00:00:00-04:00    7496869888
# 2022-03-28 00:00:00-04:00    7507230208
# 2022-03-31 00:00:00-04:00    7496869888
# 2022-04-01 00:00:00-04:00    7631819776
# 2022-04-02 00:00:00-04:00    7496869888
# 2022-04-29 00:00:00-04:00    7479029760
# 2022-06-09 00:00:00-04:00    7536840192
# 2022-06-13 00:00:00-04:00    7479029760
# 2022-07-28 00:00:00-04:00    7464000000
# 2022-08-01 00:00:00-04:00    7457889792
# 2022-08-25 00:00:00-04:00    7475469824
# 2022-08-26 00:00:00-04:00    7457889792
# 2022-09-01 00:00:00-04:00    7457889792
# 2022-09-02 00:00:00-04:00    7488540160
# 2022-09-02 00:00:00-04:00    7457889792
# 2022-09-10 00:00:00-04:00    7290379776
# ...

# %%
msft.income_stmt
# Out:
#                                                         2022-06-30  \
# Tax Effect Of Unusual Items                                    0.0
# Tax Rate For Calcs                                        0.131134
# Normalized EBITDA                                    97843000000.0
# Total Unusual Items                                    334000000.0
# Total Unusual Items Excluding Goodwill                 334000000.0
# Net Income From Continuing Operation Net Minori...   72738000000.0
# Reconciled Depreciation                              14460000000.0
# Reconciled Cost Of Revenue                           62650000000.0
# EBIT                                                 83383000000.0
# Net Interest Income                                     31000000.0
# Interest Expense                                      2063000000.0
# Interest Income                                       2094000000.0
# Normalized Income                                    72738000000.0
# ...

# %%
msft.income_stmt.reset_index()['index'].unique()
# Out:
# array(['Tax Effect Of Unusual Items', 'Tax Rate For Calcs',
#        'Normalized EBITDA', 'Total Unusual Items',
#        'Total Unusual Items Excluding Goodwill',
#        'Net Income From Continuing Operation Net Minority Interest',
#        'Reconciled Depreciation', 'Reconciled Cost Of Revenue', 'EBIT',
#        'Net Interest Income', 'Interest Expense', 'Interest Income',
#        'Normalized Income',
#        'Net Income From Continuing And Discontinued Operation',
#        'Total Expenses', 'Total Operating Income As Reported',
#        'Diluted Average Shares', 'Basic Average Shares', 'Diluted EPS',
#        'Basic EPS', 'Diluted NI Availto Com Stockholders',
#        'Net Income Common Stockholders', 'Net Income',
#        'Net Income Including Noncontrolling Interests',
#        'Net Income Continuous Operations', 'Tax Provision',
#        'Pretax Income', 'Other Income Expense',
#        'Other Non Operating Income Expenses', 'Special Income Charges',
# ...

# %%
msft.quarterly_income_stmt
# Out:
#                                                        2023-03-31  \
# Tax Effect Of Unusual Items                                   0.0
# Tax Rate For Calcs                                       0.192917
# Normalized EBITDA                                   25901000000.0
# Total Unusual Items                                   162000000.0
# Total Unusual Items Excluding Goodwill                162000000.0
# Net Income From Continuing Operation Net Minori...  18299000000.0
# Reconciled Depreciation                              3549000000.0
# Reconciled Cost Of Revenue                          16128000000.0
# EBIT                                                22352000000.0
# Net Interest Income                                   252000000.0
# Interest Expense                                      496000000.0
# Interest Income                                       748000000.0
# Normalized Income                                   18299000000.0
# ...

# %%
msft.balance_sheet.head(50)
# Out:
#                                                         2022-06-30  \
# Ordinary Shares Number                                7464000000.0
# Share Issued                                          7464000000.0
# Net Debt                                             35850000000.0
# Total Debt                                           61270000000.0
# Tangible Book Value                                  87720000000.0
# Invested Capital                                    216323000000.0
# Working Capital                                      74602000000.0
# Net Tangible Assets                                  87720000000.0
# Capital Lease Obligations                            11489000000.0
# Common Stock Equity                                 166542000000.0
# Total Capitalization                                213574000000.0
# Total Equity Gross Minority Interest                166542000000.0
# Stockholders Equity                                 166542000000.0
# ...

# %%
msft.balance_sheet.tail(24)
# Out:
#                                                       2022-06-30  \
# Accumulated Depreciation                          -59660000000.0
# Gross PPE                                         147206000000.0
# Leases                                              7819000000.0
# Other Properties                                  147206000000.0
# Machinery Furniture Equipment                      66491000000.0
# Buildings And Improvements                         55014000000.0
# Land And Improvements                               4734000000.0
# Properties                                                   0.0
# Current Assets                                    169684000000.0
# Other Current Assets                               16924000000.0
# Hedging Assets Current                                 8000000.0
# Inventory                                           3742000000.0
# Finished Goods                                      2516000000.0
# ...

# %%
msft.quarterly_balance_sheet.head(37)
# Out:
#                                                       2023-03-31  \
# Ordinary Shares Number                              7437000000.0
# Share Issued                                        7437000000.0
# Net Debt                                           21648000000.0
# Total Debt                                         60522000000.0
# Tangible Book Value                               116864000000.0
# ...                                                          ...
# Cash Cash Equivalents And Short Term Investments  104427000000.0
# Other Short Term Investments                       77865000000.0
# Cash And Cash Equivalents                          26562000000.0
# Cash Equivalents                                   18053000000.0
# Cash Financial                                      8509000000.0
#
#                                                       2022-12-31  \
# Ordinary Shares Number                              7447000000.0
# ...

# %%
msft.quarterly_balance_sheet.tail(37)
# Out:
#                                                       2023-03-31  \
# Payables                                           19468000000.0
# Total Tax Payable                                   4163000000.0
# Income Tax Payable                                  4163000000.0
# Accounts Payable                                   15305000000.0
# Total Assets                                      380088000000.0
# Total Non Current Assets                          216199000000.0
# Other Non Current Assets                           26954000000.0
# Investments And Advances                            9415000000.0
# Long Term Equity Investment                         9415000000.0
# Goodwill And Other Intangible Assets               77819000000.0
# Other Intangible Assets                             9879000000.0
# Goodwill                                           67940000000.0
# Net PPE                                           102011000000.0
# ...

# %%
msft.cashflow
# Out:
#                                                    2022-06-30     2021-06-30  \
# Free Cash Flow                                  65149000000.0  56118000000.0
# Repurchase Of Capital Stock                    -32696000000.0 -27385000000.0
# Repayment Of Debt                               -9023000000.0  -3750000000.0
# Issuance Of Debt                                          NaN            NaN
# Issuance Of Capital Stock                        1841000000.0   1693000000.0
# Capital Expenditure                            -23886000000.0 -20622000000.0
# End Cash Position                               13931000000.0  14224000000.0
# Beginning Cash Position                         14224000000.0  13576000000.0
# Effect Of Exchange Rate Changes                  -141000000.0    -29000000.0
# Changes In Cash                                  -152000000.0    677000000.0
# Financing Cash Flow                            -58876000000.0 -48486000000.0
# ...

# %%
msft.quarterly_cashflow
# Out:
#                                                    2023-03-31     2022-12-31  \
# Free Cash Flow                                  17834000000.0   4899000000.0
# Repurchase Of Capital Stock                     -5509000000.0  -5459000000.0
# Repayment Of Debt                                         0.0   -750000000.0
# Issuance Of Capital Stock                         536000000.0    243000000.0
# Capital Expenditure                             -6607000000.0  -6274000000.0
# End Cash Position                               26562000000.0  15646000000.0
# Beginning Cash Position                         15646000000.0  22884000000.0
# Effect Of Exchange Rate Changes                    29000000.0     88000000.0
# Changes In Cash                                 10887000000.0  -7326000000.0
# Financing Cash Flow                            -10290000000.0 -11349000000.0
# Cash Flow From Continuing Financing Activities -10290000000.0 -11349000000.0
# ...

# %%
msft.major_holders
# Out:
#         0                                      1
# 0   0.05%        % of Shares Held by All Insider
# 1  73.77%       % of Shares Held by Institutions
# 2  73.80%        % of Float Held by Institutions
# 3    6159  Number of Institutions Holding Shares

# %%
msft.institutional_holders
# Out:
#                               Holder     Shares Date Reported   % Out  \
# 0         Vanguard Group, Inc. (The)  649516597    2023-03-30  0.0874
# 1                     Blackrock Inc.  537573096    2023-03-30  0.0723
# 2           State Street Corporation  292106885    2023-03-30  0.0393
# 3                           FMR, LLC  200523373    2023-03-30  0.0270
# 4      Price (T.Rowe) Associates Inc  166035734    2023-03-30  0.0223
# 5      Geode Capital Management, LLC  144365760    2023-03-30  0.0194
# 6                     Morgan Stanley  120316895    2023-03-30  0.0162
# 7          JP Morgan Chase & Company   94617741    2023-03-30  0.0127
# 8            Capital World Investors   87608980    2023-03-30  0.0118
# 9  Norges Bank Investment Management   86316926    2022-12-30  0.0116
#
#           Value
# 0  219029987633
# 1  181280400089
# 2   98504284116
# 3   67620492087
# 4   55990570422
# 5   48683021763
# 6   40573263478
# 7   31906994735
# 8   29543500342
# 9   29107793891

# %%
msft.mutualfund_holders
# Out:
#                                               Holder     Shares Date Reported  \
# 0             Vanguard Total Stock Market Index Fund  226594602    2022-12-30
# 1                            Vanguard 500 Index Fund  172326589    2022-12-30
# 2                            Fidelity 500 Index Fund   81720092    2023-02-27
# 3                             SPDR S&P 500 ETF Trust   80591530    2023-03-30
# 4        Invesco ETF Tr-Invesco QQQ Tr, Series 1 ETF   75130340    2023-03-30
# 5                           iShares Core S&P 500 ETF   66532494    2023-02-27
# 6                         Vanguard Growth Index Fund   62920006    2022-12-30
# 7  Vanguard Institutional Index Fund-Institutiona...   52237514    2022-12-30
# 8                         Growth Fund Of America Inc   41256784    2023-03-30
# 9         Vanguard Information Technology Index Fund   34018479    2022-11-29
#
#     % Out        Value
# 0  0.0304  76412231963
# 1  0.0232  58111972552
# 2  0.0110  27557649523
# ...

# %%
msft.earnings_dates
# Out:
#                            EPS Estimate  Reported EPS  Surprise(%)
# Earnings Date
# 2024-04-23 06:00:00-04:00           NaN           NaN          NaN
# 2024-01-22 16:00:00-05:00           NaN           NaN          NaN
# 2024-01-22 05:00:00-05:00           NaN           NaN          NaN
# 2023-10-23 06:00:00-04:00           NaN           NaN          NaN
# 2023-07-24 06:00:00-04:00          2.55           NaN          NaN
# 2023-04-25 12:00:00-04:00          2.23          2.45       0.0981
# 2023-01-24 11:00:00-05:00          2.29          2.32       0.0109
# 2022-10-25 12:00:00-04:00          2.30          2.35       0.0205
# 2022-07-26 12:00:00-04:00          2.29          2.23      -0.0274
# 2022-04-26 12:00:00-04:00          2.19          2.22       0.0160
# 2022-01-25 11:00:00-05:00          2.31          2.48       0.0725
# 2021-10-26 12:00:00-04:00          2.07          2.27       0.0941

# %%
msft.isin
# Out:
# '-'

# %%
msft.options
# Out:
# ('2023-07-14',
#  '2023-07-21',
#  '2023-07-28',
#  '2023-08-04',
#  '2023-08-11',
#  '2023-08-18',
#  '2023-08-25',
#  '2023-09-15',
#  '2023-10-20',
#  '2023-11-17',
#  '2023-12-15',
#  '2024-01-19',
#  '2024-02-16',
#  '2024-03-15',
#  '2024-06-21',
#  '2024-12-20',
#  '2025-01-17',
#  '2025-06-20',
#  '2025-12-19')

# %%
pd.DataFrame(msft.news)
# Out:
#                                    uuid  \
# 0  70c450b1-c46a-3f2d-a5ea-0e2ddbea7adf
# 1  ce47654e-05f4-3ef1-9408-14eb714017f0
# 2  511499a4-2f31-3bc6-8f47-de7554f0dff8
# 3  9b530dc1-d2c4-389c-9de7-a557a5ec1242
# 4  ccd1eeb9-01ce-3516-8a0d-d9501a34d31d
# 5  84dbe3fa-8648-3dc5-a273-f55e4ba2ad12
# 6  7b305c2e-a66b-3566-afe3-9b00783af8d0
# 7  386217ee-c9ef-379a-abb0-c5217586cedd
#
#                                                title  \
# 0  Nasdaq 100 Plans Special Rebalance To Curb Dom...
# 1  Microsoft Corporation (MSFT) Generated Strong ...
# 2  Should You Buy the 3 Top Stocks in Warren Buff...
# 3  15 Least Tax Friendly States For Middle Class ...
# 4  What Amazon, Microsoft, and DigitalOceon Inves...
# 5  In Battle With Microsoft, Google Bets on Medic...
# 6  Wall Street Says Artificial Intelligence (AI) ...
# 7                                     Weekly Roundup
#
#                    publisher  \
# 0  Investor's Business Daily
# 1             Insider Monkey
# ...

# %%
opt = msft.option_chain('2023-09-15')
opt.calls
# Out:
#          contractSymbol             lastTradeDate  strike  lastPrice    bid  \
# 0   MSFT230915C00110000 2023-07-06 14:04:54+00:00   110.0     228.55    0.0
# 1   MSFT230915C00115000 2023-02-14 15:07:22+00:00   115.0     160.06  151.4
# 2   MSFT230915C00120000 2023-03-02 14:34:50+00:00   120.0     129.30  168.0
# 3   MSFT230915C00125000 2023-04-26 19:58:28+00:00   125.0     172.00  208.0
# 4   MSFT230915C00130000 2023-03-01 20:07:30+00:00   130.0     119.46  158.0
# ..                  ...                       ...     ...        ...    ...
# 74  MSFT230915C00480000 2023-06-30 14:24:23+00:00   480.0       0.16    0.0
# 75  MSFT230915C00485000 2023-07-03 15:22:59+00:00   485.0       0.11    0.0
# 76  MSFT230915C00490000 2023-07-03 14:30:26+00:00   490.0       0.08    0.0
# 77  MSFT230915C00495000 2023-07-05 17:25:00+00:00   495.0       0.10    0.0
# 78  MSFT230915C00500000 2023-07-07 17:06:05+00:00   500.0       0.07    0.0
#
# ...

# %%
opt.puts
# Out:
#          contractSymbol             lastTradeDate  strike  lastPrice    bid  \
# 0   MSFT230915P00110000 2023-07-07 18:29:44+00:00   110.0       0.02    0.0
# 1   MSFT230915P00115000 2023-06-22 13:57:39+00:00   115.0       0.02    0.0
# 2   MSFT230915P00120000 2023-05-31 19:27:06+00:00   120.0       0.02    0.0
# 3   MSFT230915P00125000 2023-06-08 15:59:01+00:00   125.0       0.03    0.0
# 4   MSFT230915P00130000 2023-06-23 15:01:09+00:00   130.0       0.02    0.0
# ..                  ...                       ...     ...        ...    ...
# 69  MSFT230915P00460000 2023-05-17 14:14:31+00:00   460.0     148.45  115.0
# 70  MSFT230915P00465000 2023-07-05 17:34:44+00:00   465.0     126.55    0.0
# 71  MSFT230915P00470000 2023-07-05 15:43:13+00:00   470.0     130.97    0.0
# 72  MSFT230915P00490000 2023-06-29 19:20:55+00:00   490.0     155.91    0.0
# 73  MSFT230915P00500000 2023-06-30 19:59:57+00:00   500.0     159.60    0.0
#
# ...

# %%
tickers = yf.Tickers('msft aapl goog')
tickers
# Out:
# yfinance.Tickers object <MSFT,AAPL,GOOG>

# %%
tickers.tickers['MSFT'].info
# Out:
# {'address1': 'One Microsoft Way',
#  'city': 'Redmond',
#  'state': 'WA',
#  'zip': '98052-6399',
#  'country': 'United States',
#  'phone': '425 882 8080',
#  'fax': '425 706 7329',
#  'website': 'https://www.microsoft.com',
#  'industry': 'Software—Infrastructure',
#  'industryDisp': 'Software—Infrastructure',
#  'sector': 'Technology',
# ...

# %%
tickers.tickers['AAPL'].splits
# Out:
# Date
# 1987-06-16 00:00:00-04:00    2.0
# 2000-06-21 00:00:00-04:00    2.0
# 2005-02-28 00:00:00-05:00    2.0
# 2014-06-09 00:00:00-04:00    7.0
# 2020-08-31 00:00:00-04:00    4.0
# Name: Stock Splits, dtype: float64

# %%
tickers.tickers['GOOG'].actions
# Out:
#                            Dividends  Stock Splits
# Date
# 2014-03-27 00:00:00-04:00        0.0      2.002000
# 2015-04-27 00:00:00-04:00        0.0      1.002746
# 2022-07-18 00:00:00-04:00        0.0     20.000000

# %%
data = yf.download('SPY', start = '2018-02-02', end = '2023-02-02')
data
# Out:
# [*********************100%***********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2018-02-02  280.079987  280.230011  275.410004  275.450012  251.005936
# 2018-02-05  273.450012  275.850006  263.309998  263.929993  240.508224
# 2018-02-06  259.940002  269.700012  258.700012  269.130005  245.246719
# 2018-02-07  268.500000  272.359985  267.579987  267.670013  243.916275
# 2018-02-08  268.010010  268.170013  257.589996  257.630005  234.767227
# ...                ...         ...         ...         ...         ...
# 2023-01-26  403.130005  404.920013  400.029999  404.750000  401.718903
# 2023-01-27  403.660004  408.160004  403.440002  405.679993  402.641937
# 2023-01-30  402.799988  405.130005  400.279999  400.589996  397.590088
# 2023-01-31  401.130005  406.529999  400.769989  406.480011  403.435974
# 2023-02-01  405.209991  413.670013  402.350006  410.799988  407.723572
#
#                Volume
# Date
# ...

# %%
yf.download(tickers = 'MSFT TSLA',
           period= '5y',
           interval = '3mo',
           prepost = False,
           repair = True)
# Out:
# [*********************100%***********************]  2 of 2 completed
#              Adj Close                   Close                    High  \
#                   MSFT        TSLA        MSFT        TSLA        MSFT
# Date
# 2018-07-01  108.170906   17.651333  114.370003   17.651333  115.290001
# 2018-10-01   96.434357   22.186666  101.570000   22.186666  116.180000
# 2019-01-01  112.460411   18.657333  117.940002   18.657333  120.820000
# 2019-04-01  128.281631   14.897333  133.960007   14.897333  138.399994
# 2019-07-01  133.629532   16.058001  139.029999   16.058001  142.369995
# 2019-10-01  152.079071   27.888666  157.699997   27.888666  159.550003
# 2020-01-01  152.606232   34.933334  157.710007   34.933334  190.699997
# 2020-04-01  197.461914   71.987335  203.509995   71.987335  204.399994
# 2020-07-01  204.647598  143.003326  210.330002  143.003326  232.860001
# 2020-10-01  216.934113  235.223328  222.419998  235.223328  228.119995
# ...

# %% [markdown]
# ### smarter scraping

# %% [markdown]
# ### requests

# %%
import requests_cache
session = requests_cache.CachedSession('yfinance.cache')
session.headers['User-agent'] = 'my-program/1.0'
ticker = yf.Ticker('msft', session=session)
# The scraped response will be stored in the cache
ticker.actions
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 import requests_cache
#       2 session = requests_cache.CachedSession('yfinance.cache')
#       3 session.headers['User-agent'] = 'my-program/1.0'
#
# ModuleNotFoundError: No module named 'requests_cache'

# %%
from requests import Session
from requests_cache import CacheMixin, SQLiteCache
from requests_ratelimiter import LimiterMixin, MemoryQueueBucket
from pyrate_limiter import Duration, RequestRate, Limiter
class CachedLimiterSession(CacheMixin, LimiterMixin, Session):
    pass

session = CachedLimiterSession(
    limiter=Limiter(RequestRate(2, Duration.SECOND*5),  # max 2 requests per 5 seconds
    bucket_class=MemoryQueueBucket,
    backend=SQLiteCache("yfinance.cache"),
)

# %%
from pandas_datareader import data as pdr

import yfinance as yf
yf.pdr_override() # <== that's all it takes :-)

# download dataframe
data = pdr.get_data_yahoo("SPY", start="2017-01-01", end="2017-04-30")

# %% [markdown]
# ---

# %%
stop

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# Allocation--15% to 30% Equity
# Allocation--30% to 50% Equity
# Allocation--50% to 70% Equity
# Allocation--70% to 85% Equity
# Allocation--85%+ Equity
# Bank Loan
# Bear Market
# China Region
# Commodities Agriculture
# Commodities Broad Basket
# Convertibles
# Corporate Bond
# Diversified Emerging Mkts
# Diversified Pacific/Asia
# Emerging Markets Bond
# Emerging-Markets Local-Currency Bond
# Energy Limited Partnership
# Equity Energy
# Equity Precious Metals
# Europe Stock
# Financial
# Foreign Large Blend
# Foreign Large Growth
# Foreign Large Value
# Foreign Small/Mid Blend
# Foreign Small/Mid Growth
# Foreign Small/Mid Value
# Global Real Estate
# Health
# High Yield Bond
# High Yield Muni
# Inflation-Protected Bond
# Infrastructure
# Intermediate Government
# Intermediate-Term Bond
# Japan Stock
# Large Blend
# Large Growth
# Large Value
# Long Government
# Long-Short Credit
# Long-Short Equity
# Long-Term Bond
# Managed Futures
# Market Neutral
# Mid-Cap Blend
# Mid-Cap Growth
# Mid-Cap Value
# Miscellaneous Region
# Multialternative
# Multicurrency
# Multisector Bond
# Muni California Intermediate
# Muni California Long
# Muni Massachusetts
# Muni Minnesota
# Muni National Interm
# Muni National Long
# Muni National Short
# Muni New Jersey
# Muni New York Intermediate
# Muni New York Long
# Muni Ohio
# Muni Pennsylvania
# Muni Single State Interm
# Muni Single State Long
# Muni Single State Short
# Natural Resources
# Nontraditional Bond
# Option Writing
# Other
# Other Allocation
# Pacific/Asia ex-Japan Stk
# Preferred Stock
# Real Estate
# Short Government
# Short-Term Bond
# Small Blend
# Small Growth
# Small Value
# Tactical Allocation
# Target-Date 2000-2010
# Target-Date 2015
# Target-Date 2020
# Target-Date 2025
# Target-Date 2030
# Target-Date 2035
# Target-Date 2040
# Target-Date 2045
# Target-Date 2050
# Target-Date 2055
# Target-Date 2060+
# Target-Date Retirement
# Technology
# Trading - Leveraged/Inverse Commodities
# Trading - Leveraged/Inverse Equity
# Trading--Inverse Equity
# Trading--Leveraged Equity
# Ultrashort Bond
# Utilities
# World Allocation
# World Bond
# World Stock
