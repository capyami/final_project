# %% [markdown]
# ### inputs:
#
# currency (list)
#
# country (list)
#
# category (list)
#
# category_group (list)
#
# market (list)
#
# summary (example: biotech)
#
# name (example:ucits, if ucits, no category, category_group, but yes currecency and market)
#
# summary as info of ETF in final data frame

# %%
import financedatabase as fd
import pandas as pd
import numpy as np

# %%
etfs = fd.ETFs()

# %%
ucits = etfs.search(name='financial')

# %%
ucits
# Out:
#                                                       name currency  \
# symbol
# 1596.T                        NZAM ETF TOPIX Ex-Financials      JPY
# AFIN.DE  Amundi Index Solutions - Amundi EURO Corporate...      EUR
# AFIN.F   Amundi Index Solutions - Amundi EURO Corporate...      EUR
# AFIN.MI  Amundi Index Solutions - Amundi EURO Corporate...      EUR
# AFIN.PA  Amundi Index Solutions - Amundi EURO Corporate...      EUR
# ...                                                    ...      ...
# BHF                            Brighthouse Financial, Inc.      NaN
# BHFAN                          Brighthouse Financial, Inc.      NaN
# BHFAO                          Brighthouse Financial, Inc.      NaN
# BHFAP                          Brighthouse Financial, Inc.      NaN
# BROC.MU                        Brighthouse Financial, Inc.      NaN
#
#                                                    summary category_group  \
# symbol
# 1596.T                                                 NaN            NaN
# AFIN.DE  To track the performance of Markit iBoxx Euro ...            NaN
# AFIN.F   To track the performance of Markit iBoxx Euro ...            NaN
# AFIN.MI  To track the performance of Markit iBoxx Euro ...            NaN
# AFIN.PA  To track the performance of Markit iBoxx Euro ...            NaN
# ...                                                    ...            ...
# BHF                                                    NaN            NaN
# BHFAN                                                  NaN            NaN
# BHFAO                                                  NaN            NaN
# BHFAP                                                  NaN            NaN
# BROC.MU                                                NaN            NaN
#
#         category                                    family exchange     market
# symbol
# 1596.T       NaN  Norinchukin Zenkyoren Asset Mgmt Co.,Ltd      JPX  jp_market
# AFIN.DE      NaN                   Amundi Asset Management      GER  de_market
# AFIN.F       NaN                   Amundi Asset Management      FRA  dr_market
# AFIN.MI      NaN                   Amundi Asset Management      MIL  it_market
# AFIN.PA      NaN                   Amundi Asset Management      PAR  fr_market
# ...          ...                                       ...      ...        ...
# BHF          NaN                                       NaN      NaN        NaN
# BHFAN        NaN                                       NaN      NaN        NaN
# BHFAO        NaN                                       NaN      NaN        NaN
# BHFAP        NaN                                       NaN      NaN        NaN
# BROC.MU      NaN                                       NaN      NaN        NaN
#
# [178 rows x 8 columns]

# %%
ucits['market'].unique()
# Out:
# array(['jp_market', 'de_market', 'dr_market', 'es_market', 'nl_market',
#        'it_market', 'gb_market', 'fr_market', 'ch_market', 'gr_market',
#        'mx_market', 'at_market', 'be_market', 'us_market', 'hu_market',
#        'ru_market', 'sg_market', 'il_market', 'ic_market', 'se_market',
#        'pt_market', 'fi_market', nan], dtype=object)

# %%
ucits['category'].unique()
# Out:
# array([nan], dtype=object)

# %%
etfs.select()['category'].unique()
# Out:
# array([nan, 'Emerging Markets', 'Factors', 'Energy', 'Bonds',
#        'Developed Markets', 'Health Care', 'Trading', 'Technology',
#        'Industrials', 'Equities', 'Materials', 'Consumer Discretionary',
#        'Real Estate', 'Commodities Broad Basket', 'Financials',
#        'Currencies', 'Derivatives', 'Alternative', 'Utilities',
#        'Communications', 'Consumer Staples'], dtype=object)

# %%
etfs.select()['summary'].unique()[1]

# %%
len(etfs.options('category'))
# Out:
# 21

# %%
tickers = list(etfs.index)

# %%
list_etf = yf.download(tickers, start="2020-01-01", end="2020-06-01")['Adj Close']
list_etf = stock_data_biotech.dropna(axis='columns')

# %%
prueba_ucits = ucits.reset_index()

# %%
prueba_ucits.search(name='Metals')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 prueba_ucits.search(name='Metals')
#
# File ~\miniconda3\envs\tf\lib\site-packages\pandas\core\generic.py:5902, in NDFrame.__getattr__(self, name)
#    5895 if (
#    5896     name not in self._internal_names_set
#    5897     and name not in self._metadata
#    5898     and name not in self._accessors
#    5899     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900 ):
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'search'

# %%
prueba_etfs = etfs.select().reset_index()

# %%
prueba_etfs
# Out:
#         symbol                                               name currency  \
# 0        ^ACWI                                      ISHARES TRUST      USD
# 1     ^ADFI-IV                    NFIELD DYNAMIC FIXED INCOME ETF      USD
# 2        ^ADRE                                 INVESCO ACTIVELY M      USD
# 3      ^ARB-EU                     ALTSHARES MERGER ARBITRAGE ETF      USD
# 4      ^ARB-IV                     ALTSHARES MERGER ARBITRAGE ETF      USD
# ...        ...                                                ...      ...
# 2855     VGFPF  Vanguard Funds Public Limited Company - Vangua...      NaN
# 2856     VFDEF  Vanguard Funds Public Limited Company - Vangua...      NaN
# 2857     WSDMF  WisdomTree Issuer ICAV - WisdomTree Europe Equ...      NaN
# 2858     WDSSF  WisdomTree Issuer ICAV - WisdomTree US Quality...      NaN
# 2859     ZKBHF                                       ZKB Gold ETF      NaN
#
#      summary category_group category family exchange     market
# 0        NaN            NaN      NaN    NaN      NIM  us_market
# 1        NaN            NaN      NaN    NaN      ASE  us_market
# 2        NaN            NaN      NaN    NaN      NIM  us_market
# 3        NaN            NaN      NaN    NaN      ASE  us_market
# 4        NaN            NaN      NaN    NaN      ASE  us_market
# ...      ...            ...      ...    ...      ...        ...
# 2855     NaN            NaN      NaN    NaN      NaN        NaN
# 2856     NaN            NaN      NaN    NaN      NaN        NaN
# 2857     NaN            NaN      NaN    NaN      NaN        NaN
# 2858     NaN            NaN      NaN    NaN      NaN        NaN
# 2859     NaN            NaN      NaN    NaN      NaN        NaN
#
# [2860 rows x 9 columns]
